# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
data = pd.read_csv ("clothes.csv")

# %%
data
# Out:
#                                              title_orig  price  retail_price  \
# 0     2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1      Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2     2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3     Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4     Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
# ...                                                 ...    ...           ...
# 1568  New Fashion Women Bohemia Dandelion Print Tee ...   6.00             9
# 1569  10 Color Women Summer Shorts Lace Up Elastic W...   2.00            56
# 1570  New Men Siwmwear Beach-Shorts Men Summer Quick...   5.00            19
# 1571  Fashion Women Summer Sleeveless Dresses V Neck...  13.00            11
# 1572  Fashion Women Yoga Pants Slim Fit Fitness Runn...   7.00             6
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1573 entries, 0 to 1572
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   title_orig                 1573 non-null   object
#  1   price                      1573 non-null   float64
#  2   retail_price               1573 non-null   int64
#  3   currency_buyer             1573 non-null   object
#  4   units_sold                 1573 non-null   int64
#  5   uses_ad_boosts             1573 non-null   int64
#  6   rating                     1573 non-null   float64
#  7   rating_count               1573 non-null   int64
#  8   rating_five_count          1528 non-null   float64
#  9   rating_four_count          1528 non-null   float64
#  10  rating_three_count         1528 non-null   float64
#  11  rating_two_count           1528 non-null   float64
#  12  rating_one_count           1528 non-null   float64
# ...

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1476 entries, 0 to 1572
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   title_orig                 1476 non-null   object
#  1   price                      1476 non-null   float64
#  2   retail_price               1476 non-null   int64
#  3   currency_buyer             1476 non-null   object
#  4   units_sold                 1476 non-null   int64
#  5   uses_ad_boosts             1476 non-null   int64
#  6   rating                     1476 non-null   float64
#  7   rating_count               1476 non-null   int64
#  8   rating_five_count          1476 non-null   float64
#  9   rating_four_count          1476 non-null   float64
#  10  rating_three_count         1476 non-null   float64
#  11  rating_two_count           1476 non-null   float64
#  12  rating_one_count           1476 non-null   float64
# ...

# %%
from sklearn.model_selection import train_test_split
X = data.drop (['price'], axis=1)
y = data[ 'price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
train_data = X_train. join (y_train)
train_data
# Out:
#                                              title_orig  retail_price  \
# 1480  Women Summer Casual Loose Sling Dress V-neck B...            14
# 422   Plus Size Women's Fashion Loose Casual Leaf pr...             6
# 1570  New Men Siwmwear Beach-Shorts Men Summer Quick...            19
# 714   Women's Summer Fashion Spaghetti Strap Floral ...             9
# 409   Women Summer Print Striped Casual Dress Tank D...             7
# ...                                                 ...           ...
# 113   Fashion Women Denim Shorts Stitching Lace Summ...             5
# 646   Summer Women Lace Hollow Backless Irregular Fl...             6
# 769   Women Summer Shorts Lace Up Elastic Waistband ...             3
# 1352  New Summer Women Fashion Pullovers Short Sleev...            83
# 762    New Fashion Autumn Summer Women's Long Sleeve...            17
#
#      currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# ...

# %%
train_data.hist(figsize=(16,16))
# Out:
# array([[<AxesSubplot:title={'center':'retail_price'}>,
#         <AxesSubplot:title={'center':'units_sold'}>,
#         <AxesSubplot:title={'center':'uses_ad_boosts'}>,
#         <AxesSubplot:title={'center':'rating'}>],
#        [<AxesSubplot:title={'center':'rating_count'}>,
#         <AxesSubplot:title={'center':'rating_five_count'}>,
#         <AxesSubplot:title={'center':'rating_four_count'}>,
#         <AxesSubplot:title={'center':'rating_three_count'}>],
#        [<AxesSubplot:title={'center':'rating_two_count'}>,
#         <AxesSubplot:title={'center':'rating_one_count'}>,
#         <AxesSubplot:title={'center':'merchant_rating_count'}>,
#         <AxesSubplot:title={'center':'merchant_rating'}>],
#        [<AxesSubplot:title={'center':'price'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
train_data['retail_price']=np.log(train_data['retail_price'] + 1)
train_data['price']=np.log(train_data['price'] + 1)
train_data['units_sold']=np.log(train_data['units_sold'] + 1)
train_data['uses_ad_boosts']=np.log(train_data['uses_ad_boosts'] + 1)
train_data['rating']=np.log(train_data['rating'] + 1)
train_data['rating_count']=np.log(train_data['rating_count'] + 1)
train_data['rating_five_count']=np.log(train_data['rating_five_count'] + 1)
train_data['rating_four_count']=np.log(train_data['rating_four_count'] + 1)
train_data['rating_three_count']=np.log(train_data['rating_three_count'] + 1)
train_data['rating_two_count']=np.log(train_data['rating_two_count'] + 1)
train_data['rating_one_count']=np.log(train_data['rating_one_count'] + 1)
train_data['merchant_rating_count']=np.log(train_data['merchant_rating_count'] + 1)
train_data['merchant_rating']=np.log(train_data['merchant_rating'] + 1)

# %%
train_data.hist(figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'retail_price'}>,
#         <AxesSubplot:title={'center':'units_sold'}>,
#         <AxesSubplot:title={'center':'uses_ad_boosts'}>,
#         <AxesSubplot:title={'center':'rating'}>],
#        [<AxesSubplot:title={'center':'rating_count'}>,
#         <AxesSubplot:title={'center':'rating_five_count'}>,
#         <AxesSubplot:title={'center':'rating_four_count'}>,
#         <AxesSubplot:title={'center':'rating_three_count'}>],
#        [<AxesSubplot:title={'center':'rating_two_count'}>,
#         <AxesSubplot:title={'center':'rating_one_count'}>,
#         <AxesSubplot:title={'center':'merchant_rating_count'}>,
#         <AxesSubplot:title={'center':'merchant_rating'}>],
#        [<AxesSubplot:title={'center':'price'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
train_data.product_variation_size_id.value_counts()
# Out:
# S                 499
# XS                264
# M                 160
# XXS                75
# L                  33
#                  ...
# Size-XXS            1
# daughter 24M        1
# US 6.5 (EU 37)      1
# EU 35               1
# 40 cm               1
# Name: product_variation_size_id, Length: 82, dtype: int64

# %%
plt.figure(figsize=(15, 15))
sns.scatterplot(x="rating_count", y="rating_five_count", data=train_data, hue= "units_sold", palette="coolwarm")
# Out:
# <AxesSubplot:xlabel='rating_count', ylabel='rating_five_count'>

# %%
train_data['units_per_price'] = train_data['units_sold'] / train_data['retail_price']
train_data['rating_five_ratio'] = train_data['rating_five_count'] / train_data['rating_count']

# %%
plt.figure(figsize=(15,15))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
try:
    train_data=train_data.drop(['title_orig'],axis=1)
    train_data=train_data.drop(['currency_buyer'],axis=1)
    train_data=train_data.drop(['product_color'],axis=1)
    train_data=train_data.drop(['product_variation_size_id'],axis=1)
    train_data=train_data.drop(['merchant_title'],axis=1)
    train_data=train_data.drop(['merchant_id'],axis=1)
    train_data=train_data.drop(['product_id'],axis=1)
except:
    print()

# %%
from sklearn.linear_model import LinearRegression
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler()

X_train, y_train = train_data.drop(['price'], axis=1), train_data['price']
# X_train_s = scaler.fit_transform(X_train)

reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
try:
    X_test=X_test.drop(['title_orig'],axis=1)
    X_test=X_test.drop(['currency_buyer'],axis=1)
    X_test=X_test.drop(['product_color'],axis=1)
    X_test=X_test.drop(['product_variation_size_id'],axis=1)
    X_test=X_test.drop(['merchant_title'],axis=1)
    X_test=X_test.drop(['merchant_id'],axis=1)
    X_test=X_test.drop(['product_id'],axis=1)
except:
    print()




test_data = X_test.join(y_test)

test_data['retail_price']=np.log(test_data['retail_price'] + 1)
test_data['price']=np.log(test_data['price'] + 1)
test_data['units_sold']=np.log(test_data['units_sold'] + 1)
test_data['uses_ad_boosts']=np.log(test_data['uses_ad_boosts'] + 1)
test_data['rating']=np.log(test_data['rating'] + 1)
test_data['rating_count']=np.log(test_data['rating_count'] + 1)
test_data['rating_five_count']=np.log(test_data['rating_five_count'] + 1)
test_data['rating_four_count']=np.log(test_data['rating_four_count'] + 1)
test_data['rating_three_count']=np.log(test_data['rating_three_count'] + 1)
test_data['rating_two_count']=np.log(test_data['rating_two_count'] + 1)
test_data['rating_one_count']=np.log(test_data['rating_one_count'] + 1)
test_data['merchant_rating_count']=np.log(test_data['merchant_rating_count'] + 1)
test_data['merchant_rating']=np.log(test_data['merchant_rating'] + 1)

test_data['units_per_price'] = test_data['units_sold'] / test_data['retail_price']
test_data['rating_five_ratio'] = test_data['rating_five_count'] / test_data['rating_count']

# %%
X_test, y_test = test_data.drop(['price'], axis=1), test_data['price']

# %%
train_data
# Out:
#       retail_price  units_sold  uses_ad_boosts    rating  rating_count  \
# 1480      2.708050    8.517393        0.693147  1.467874      6.533789
# 422       1.945910    4.615121        0.000000  1.609438      1.945910
# 1570      2.995732    4.615121        0.000000  1.549688      4.094345
# 714       2.302585    6.908755        0.000000  1.474763      5.476464
# 409       2.079442    8.517393        0.000000  1.463255      6.363028
# ...            ...         ...             ...       ...           ...
# 113       1.791759    4.615121        0.693147  1.667707      2.397895
# 646       1.945910    8.517393        0.693147  1.574846      7.285507
# 769       1.386294    4.615121        0.693147  1.300192      2.564949
# 1352      4.430817    6.908755        0.000000  1.532557      4.779123
# 762       2.890372    6.908755        0.693147  1.481605      5.545177
#
#       rating_five_count  rating_four_count  rating_three_count  \
# ...

# %%
test_data
# Out:
#       retail_price  units_sold  uses_ad_boosts    rating  rating_count  \
# 1247      4.948760    9.210440        0.693147  1.642873      7.555382
# 932       2.564949    4.615121        0.000000  1.308333      3.044522
# 830       2.639057    4.615121        0.693147  1.609438      1.098612
# 232       2.397895    8.517393        0.000000  1.654411      7.012115
# 1071      1.609438    4.615121        0.693147  1.410987      3.091042
# ...            ...         ...             ...       ...           ...
# 952       2.197225   10.819798        0.000000  1.574846      9.487896
# 320       2.079442    4.615121        0.000000  1.684545      4.718499
# 206       2.564949    8.517393        0.000000  1.492904      6.952729
# 53        4.110874    6.908755        0.693147  1.477049      3.637586
# 599       1.945910    4.615121        0.000000  1.638997      3.332205
#
#       rating_five_count  rating_four_count  rating_three_count  \
# ...

# %%
# X_test_s = scaler.transform(X_test)

# %%
reg.score(X_test,y_test)
# Out:
# 0.3750101157695157

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor()
forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test, y_test)
# Out:
# 0.6504659565315782

# %%
from sklearn. model_selection import GridSearchCV
forest = RandomForestRegressor()
param_grid = {
    "n_estimators": [1,5,10,100,200, 300,400,500,600,700,800,900,1000],
    "min_samples_split": [2, 4],
    "max_depth": [None, 4,8]
}
grid_search = GridSearchCV(forest, param_grid, cv=5,
                           scoring="neg_mean_squared_error",
                           return_train_score=True)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 4, 8], 'min_samples_split': [2, 4],
#                          'n_estimators': [1, 5, 10, 100, 200, 300, 400, 500,
#                                           600, 700, 800, 900, 1000]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest=grid_search.best_estimator_

# %%
best_forest.score(X_test,y_test)
# Out:
# 0.6417421716434365
